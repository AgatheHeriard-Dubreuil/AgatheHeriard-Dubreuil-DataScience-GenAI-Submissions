# %% [markdown]
# <a href="https://colab.research.google.com/github/AgatheHeriard-Dubreuil/AgatheHeriard-Dubreuil-DataScience-GenAI-Submissions/blob/main/EDA-practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# First I will create a data frame from my data using Gemini, with the prompt "create a dataframe called salary_df with the csv file EDA-DP.csv"

# %%
import pandas as pd

salary_df = pd.read_csv('EDA-DP.csv')
display(salary_df.head())
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2024               SE              FT                AI Engineer
# 1       2024               SE              FT                AI Engineer
# 2       2024               SE              FT              Data Engineer
# 3       2024               SE              FT              Data Engineer
# 4       2024               SE              FT  Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  202730             USD         202730                 US             0
# 1   92118             USD          92118                 US             0
# 2  130500             USD         130500                 US             0
# 3   96000             USD          96000                 US             0
# 4  190000             USD         190000                 US             0
#
#   company_location company_size
# 0               US            M
# ...

# %% [markdown]
# This looks fine, now I want to check for missing values, using the code from https://github.com/MJMortensonWarwick/IB2AD0_Data_Science_GenerativeAI/blob/main/5_02_Modelling_Hackathon.ipynb

# %%
salary_df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# There are no missing values, so we don't have to modify this dataframe for the moment, I can start EDA.
# I will start by doing univariate analysis on each of the columns. I will not look at the variables salary and salary_currency, since they will not give us any useful information. Instead we will just look at salary_in_usd. We can start with the numerical data.
# To determine the types of each of the columns we can ask gemini with the prompt "what are the types of values in each of the columns of the dataframe salary_df"

# %%
salary_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16534 entries, 0 to 16533
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           16534 non-null  int64
#  1   experience_level    16534 non-null  object
#  2   employment_type     16534 non-null  object
#  3   job_title           16534 non-null  object
#  4   salary              16534 non-null  int64
#  5   salary_currency     16534 non-null  object
#  6   salary_in_usd       16534 non-null  int64
#  7   employee_residence  16534 non-null  object
#  8   remote_ratio        16534 non-null  int64
#  9   company_location    16534 non-null  object
#  10  company_size        16534 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 1.4+ MB

# %% [markdown]
# This table tells us that the numerical data are the columns: work_year, salary_in_usd, remote_ratio. There is no point doing a univariate analysis of the wok year so we will just look at remote_ratio and salary_in_usd. We will us the code from the github: https://github.com/MJMortensonWarwick/IB2AD0_Data_Science_GenerativeAI/blob/main/3_0X_Statistical_Exploratory_Data_Analysis.ipynb

# %%
print("Salary in USD")
print(f"Mean Income: {round(salary_df['salary_in_usd'].mean(),2)}")
print(f"Median Income: {round(salary_df['salary_in_usd'].median(),2)}")
print(f"Mode Income: {round(salary_df['salary_in_usd'].mode()[0],2)}")

print("\nRemote Ratio")
print(f"Mean Income: {round(salary_df['remote_ratio'].mean(),2)}")
print(f"Median Income: {round(salary_df['remote_ratio'].median(),2)}")
print(f"Mode Income: {round(salary_df['remote_ratio'].mode()[0],2)}")
# Out:
# Salary in USD
# Mean Income: 149686.78
# Median Income: 141300.0
# Mode Income: 150000
#
# Remote Ratio
# Mean Income: 32.0
# Median Income: 0.0
# Mode Income: 0

# %% [markdown]
# The remote ratio data does not seem to give any meaningful numerical analysis. I will use the following code to check how many unique values there are in the column. https://github.com/MJMortensonWarwick/IB2AD0_Data_Science_GenerativeAI/blob/main/5_02_Modelling_Hackathon.ipynb

# %%
print(f"Unique values for 'Remote Ratio': {salary_df['remote_ratio'].unique()}")
# Out:
# Unique values for 'Remote Ratio': [  0 100  50]
